# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !wget https://www.dropbox.com/s/jztol5j7hvm2w96/brain_tumor%20data%20set.zip

# %%
# !unzip '/content/brain_tumor data set.zip'

# %%
# !rm '/content/brain_tumor data set.zip'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os
import shutil
import math
import imutils
import cv2

# %%
ROOT_DIR='/content/Brain Tumor Data Set'

num_of_images={}

for dir in os.listdir(ROOT_DIR):
  num_of_images[dir]=len(os.listdir(os.path.join(ROOT_DIR,dir)))

num_of_images
# Out:
# {'Brain Tumor': 2513, 'Healthey': 2087}

# %%
if not os.path.exists("./train"):
  os.mkdir("./train")

  for dir in os.listdir(ROOT_DIR):
    os.makedirs("./train/"+dir)
    for img in np.random.choice(a=os.listdir(os.path.join(ROOT_DIR,dir)),
                                size=(math.floor(70/100*num_of_images[dir])-5),replace=False):
      O=os.path.join(ROOT_DIR,dir,img)
      D=os.path.join("./train",dir)
      shutil.copy(O,D)
      os.remove(O)
else:
  print("Train Folder Exists")

# %%
if not os.path.exists("./val"):
  os.mkdir("./val")

  for dir in os.listdir(ROOT_DIR):
    os.makedirs("./val/"+dir)
    for img in np.random.choice(a=os.listdir(os.path.join(ROOT_DIR,dir)),
                                size=(math.floor(15/100*num_of_images[dir])-5),replace=False):
      O=os.path.join(ROOT_DIR,dir,img)
      D=os.path.join("./val",dir)
      shutil.copy(O,D)
      os.remove(O)
else:
  print("Val Folder Exists")

# %%
if not os.path.exists("./test"):
  os.mkdir("./test")

  for dir in os.listdir(ROOT_DIR):
    os.makedirs("./test/"+dir)
    for img in np.random.choice(a=os.listdir(os.path.join(ROOT_DIR,dir)),
                                size=(math.floor(15/100*num_of_images[dir])-5),replace=False):
      O=os.path.join(ROOT_DIR,dir,img)
      D=os.path.join("./test",dir)
      shutil.copy(O,D)
      os.remove(O)
else:
  print("Test Folder Exists")

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization,MaxPooling2D,GlobalAvgPool2D
from keras.models import Sequential
from keras.preprocessing import image
import keras

# %%
model=Sequential()
model.add(Conv2D(filters=16,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)))

model.add(Conv2D(filters=32,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=128,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Dropout(rate=0.25))

model.add(Flatten())
model.add(Dense(units=64,activation='relu'))
model.add(Dropout(rate=0.25))
model.add(Dense(units=1,activation='sigmoid'))
#how the training should proceed and this is important`
model.compile(loss=keras.losses.binary_crossentropy,optimizer='adam',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 16)      448
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 32)      4640
#
#  max_pooling2d (MaxPooling2  (None, 110, 110, 32)      0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  dropout (Dropout)           (None, 26, 26, 128)       0
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 64)                5537856
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 5635361 (21.50 MB)
# Trainable params: 5635361 (21.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
train_datagen=image.ImageDataGenerator(
    zoom_range=0.2,shear_range=0.2,rescale=1./255,horizontal_flip=True
)
val_datagen=image.ImageDataGenerator(rescale=1./255)
test_datagen=image.ImageDataGenerator(rescale=1./255)

# %%
train_data=train_datagen.flow_from_directory(directory='/content/train',target_size=(224,224),batch_size=32,
                                             class_mode='binary')
# Out:
# Found 3209 images belonging to 2 classes.

# %%
train_data.class_indices
# Out:
# {'Brain Tumor': 0, 'Healthey': 1}

# %%
val_data=val_datagen.flow_from_directory(directory='/content/val',target_size=(224,224),batch_size=32,
                                             class_mode='binary')
# Out:
# Found 679 images belonging to 2 classes.

# %%
test_data=test_datagen.flow_from_directory(directory='/content/test',target_size=(224,224),batch_size=32,
                                             class_mode='binary')
# Out:
# Found 679 images belonging to 2 classes.

# %%
from keras.callbacks import ModelCheckpoint,EarlyStopping

es=EarlyStopping(monitor='val_accuracy',min_delta=0.01,patience=5,verbose=1,mode='auto')

mc=ModelCheckpoint(filepath='best_model.h5',monitor='val_accuracy',verbose=1,save_best_only=True,mode='auto')

call_back=[es,mc]

# %%
hist=model.fit_generator(generator=train_data,
                         steps_per_epoch=8,
                         epochs=30,verbose=1,
                         validation_data=val_data,
                         validation_steps=16,
                         callbacks=call_back)
# Out:
# Epoch 1/30
# 8/8 [==============================] - ETA: 0s - loss: 0.6964 - accuracy: 0.5352
# Epoch 1: val_accuracy improved from -inf to 0.59766, saving model to best_model.h5
# 8/8 [==============================] - 15s 741ms/step - loss: 0.6964 - accuracy: 0.5352 - val_loss: 0.6456 - val_accuracy: 0.5977
# Epoch 2/30
# 8/8 [==============================] - ETA: 0s - loss: 0.6770 - accuracy: 0.5781
# Epoch 2: val_accuracy improved from 0.59766 to 0.65039, saving model to best_model.h5
# 8/8 [==============================] - 5s 628ms/step - loss: 0.6770 - accuracy: 0.5781 - val_loss: 0.6407 - val_accuracy: 0.6504
# Epoch 3/30
# 8/8 [==============================] - ETA: 0s - loss: 0.6461 - accuracy: 0.6133
# Epoch 3: val_accuracy did not improve from 0.65039
# 8/8 [==============================] - 7s 942ms/step - loss: 0.6461 - accuracy: 0.6133 - val_loss: 0.6105 - val_accuracy: 0.6074
# Epoch 4/30
# 8/8 [==============================] - ETA: 0s - loss: 0.6189 - accuracy: 0.6289
# Epoch 4: val_accuracy improved from 0.65039 to 0.69336, saving model to best_model.h5
# 8/8 [==============================] - 6s 757ms/step - loss: 0.6189 - accuracy: 0.6289 - val_loss: 0.6065 - val_accuracy: 0.6934
# Epoch 5/30
# 8/8 [==============================] - ETA: 0s - loss: 0.6368 - accuracy: 0.6484
# Epoch 5: val_accuracy improved from 0.69336 to 0.72070, saving model to best_model.h5
# 8/8 [==============================] - 6s 819ms/step - loss: 0.6368 - accuracy: 0.6484 - val_loss: 0.5922 - val_accuracy: 0.7207
# Epoch 6/30
# 8/8 [==============================] - ETA: 0s - loss: 0.6490 - accuracy: 0.6328
# Epoch 6: val_accuracy improved from 0.72070 to 0.74219, saving model to best_model.h5
# 8/8 [==============================] - 5s 662ms/step - loss: 0.6490 - accuracy: 0.6328 - val_loss: 0.5872 - val_accuracy: 0.7422
# Epoch 7/30
# 8/8 [==============================] - ETA: 0s - loss: 0.6241 - accuracy: 0.6367
# Epoch 7: val_accuracy did not improve from 0.74219
# 8/8 [==============================] - 7s 839ms/step - loss: 0.6241 - accuracy: 0.6367 - val_loss: 0.5776 - val_accuracy: 0.6953
# Epoch 8/30
# 8/8 [==============================] - ETA: 0s - loss: 0.5953 - accuracy: 0.6992
# Epoch 8: val_accuracy did not improve from 0.74219
# 8/8 [==============================] - 5s 575ms/step - loss: 0.5953 - accuracy: 0.6992 - val_loss: 0.5293 - val_accuracy: 0.7422
# Epoch 9/30
# 8/8 [==============================] - ETA: 0s - loss: 0.5046 - accuracy: 0.7578
# Epoch 9: val_accuracy improved from 0.74219 to 0.79297, saving model to best_model.h5
# 8/8 [==============================] - 7s 971ms/step - loss: 0.5046 - accuracy: 0.7578 - val_loss: 0.4412 - val_accuracy: 0.7930
# Epoch 10/30
# 8/8 [==============================] - ETA: 0s - loss: 0.5661 - accuracy: 0.7253
# Epoch 10: val_accuracy did not improve from 0.79297
# 8/8 [==============================] - 5s 654ms/step - loss: 0.5661 - accuracy: 0.7253 - val_loss: 0.5012 - val_accuracy: 0.7656
# Epoch 11/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4853 - accuracy: 0.7656
# Epoch 11: val_accuracy did not improve from 0.79297
# 8/8 [==============================] - 7s 876ms/step - loss: 0.4853 - accuracy: 0.7656 - val_loss: 0.4665 - val_accuracy: 0.7637
# Epoch 12/30
# 8/8 [==============================] - ETA: 0s - loss: 0.5264 - accuracy: 0.7383
# Epoch 12: val_accuracy did not improve from 0.79297
# 8/8 [==============================] - 6s 732ms/step - loss: 0.5264 - accuracy: 0.7383 - val_loss: 0.4542 - val_accuracy: 0.7871
# Epoch 13/30
# 8/8 [==============================] - ETA: 0s - loss: 0.5007 - accuracy: 0.7578
# Epoch 13: val_accuracy improved from 0.79297 to 0.80859, saving model to best_model.h5
# 8/8 [==============================] - 5s 613ms/step - loss: 0.5007 - accuracy: 0.7578 - val_loss: 0.4234 - val_accuracy: 0.8086
# Epoch 14/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4965 - accuracy: 0.7578
# Epoch 14: val_accuracy did not improve from 0.80859
# 8/8 [==============================] - 5s 651ms/step - loss: 0.4965 - accuracy: 0.7578 - val_loss: 0.5441 - val_accuracy: 0.7168
# Epoch 15/30
# 8/8 [==============================] - ETA: 0s - loss: 0.5230 - accuracy: 0.7578
# Epoch 15: val_accuracy did not improve from 0.80859
# 8/8 [==============================] - 5s 654ms/step - loss: 0.5230 - accuracy: 0.7578 - val_loss: 0.4910 - val_accuracy: 0.7559
# Epoch 16/30
# 8/8 [==============================] - ETA: 0s - loss: 0.5162 - accuracy: 0.7811
# Epoch 16: val_accuracy did not improve from 0.80859
# 8/8 [==============================] - 4s 548ms/step - loss: 0.5162 - accuracy: 0.7811 - val_loss: 0.4269 - val_accuracy: 0.7871
# Epoch 17/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4854 - accuracy: 0.7734
# Epoch 17: val_accuracy improved from 0.80859 to 0.82031, saving model to best_model.h5
# 8/8 [==============================] - 7s 885ms/step - loss: 0.4854 - accuracy: 0.7734 - val_loss: 0.3941 - val_accuracy: 0.8203
# Epoch 18/30
# 8/8 [==============================] - ETA: 0s - loss: 0.5197 - accuracy: 0.7461
# Epoch 18: val_accuracy did not improve from 0.82031
# 8/8 [==============================] - 4s 576ms/step - loss: 0.5197 - accuracy: 0.7461 - val_loss: 0.5019 - val_accuracy: 0.7422
# Epoch 19/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4813 - accuracy: 0.7695
# Epoch 19: val_accuracy improved from 0.82031 to 0.82812, saving model to best_model.h5
# 8/8 [==============================] - 5s 694ms/step - loss: 0.4813 - accuracy: 0.7695 - val_loss: 0.4140 - val_accuracy: 0.8281
# Epoch 20/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4788 - accuracy: 0.7578
# Epoch 20: val_accuracy did not improve from 0.82812
# 8/8 [==============================] - 5s 593ms/step - loss: 0.4788 - accuracy: 0.7578 - val_loss: 0.4081 - val_accuracy: 0.8125
# Epoch 21/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4084 - accuracy: 0.8242
# Epoch 21: val_accuracy did not improve from 0.82812
# 8/8 [==============================] - 6s 781ms/step - loss: 0.4084 - accuracy: 0.8242 - val_loss: 0.4318 - val_accuracy: 0.7793
# Epoch 22/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4749 - accuracy: 0.7812
# Epoch 22: val_accuracy improved from 0.82812 to 0.83984, saving model to best_model.h5
# 8/8 [==============================] - 6s 764ms/step - loss: 0.4749 - accuracy: 0.7812 - val_loss: 0.4142 - val_accuracy: 0.8398
# Epoch 23/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4673 - accuracy: 0.7891
# Epoch 23: val_accuracy did not improve from 0.83984
# 8/8 [==============================] - 6s 737ms/step - loss: 0.4673 - accuracy: 0.7891 - val_loss: 0.4052 - val_accuracy: 0.8359
# Epoch 24/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4025 - accuracy: 0.7891
# Epoch 24: val_accuracy did not improve from 0.83984
# 8/8 [==============================] - 6s 739ms/step - loss: 0.4025 - accuracy: 0.7891 - val_loss: 0.3554 - val_accuracy: 0.8379
# Epoch 25/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4618 - accuracy: 0.7930
# Epoch 25: val_accuracy improved from 0.83984 to 0.85742, saving model to best_model.h5
# 8/8 [==============================] - 6s 827ms/step - loss: 0.4618 - accuracy: 0.7930 - val_loss: 0.3555 - val_accuracy: 0.8574
# Epoch 26/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4481 - accuracy: 0.7811
# Epoch 26: val_accuracy did not improve from 0.85742
# 8/8 [==============================] - 4s 530ms/step - loss: 0.4481 - accuracy: 0.7811 - val_loss: 0.3705 - val_accuracy: 0.8477
# Epoch 27/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4076 - accuracy: 0.8281
# Epoch 27: val_accuracy did not improve from 0.85742
# 8/8 [==============================] - 6s 805ms/step - loss: 0.4076 - accuracy: 0.8281 - val_loss: 0.3312 - val_accuracy: 0.8496
# Epoch 28/30
# 8/8 [==============================] - ETA: 0s - loss: 0.3787 - accuracy: 0.8281
# Epoch 28: val_accuracy did not improve from 0.85742
# 8/8 [==============================] - 6s 742ms/step - loss: 0.3787 - accuracy: 0.8281 - val_loss: 0.3563 - val_accuracy: 0.8262
# Epoch 29/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4152 - accuracy: 0.8164
# Epoch 29: val_accuracy did not improve from 0.85742
# 8/8 [==============================] - 5s 577ms/step - loss: 0.4152 - accuracy: 0.8164 - val_loss: 0.3705 - val_accuracy: 0.8438
# Epoch 30/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4521 - accuracy: 0.7930
# Epoch 30: val_accuracy did not improve from 0.85742
# 8/8 [==============================] - 4s 564ms/step - loss: 0.4521 - accuracy: 0.7930 - val_loss: 0.3958 - val_accuracy: 0.8359
# Epoch 30: early stopping

# %%
from keras.models import load_model

model=load_model("/content/best_model.h5")

# %%
acc=model.evaluate_generator(generator=test_data)[1]

print(f'The accuracy of your model is = {acc*100}%')
# Out:
# The accuracy of your model is = 83.0633282661438%

# %%
h=hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'],c='red')
plt.title('acc vs v-acc')
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'],c='red')
plt.title("loss vs v-loss")
plt.show()

# %%
path='/content/val/Brain Tumor/Cancer (1008).jpg'
img=image.load_img(path,target_size=(224,224),  )

i=image.img_to_array(img)/255
input_arr=np.array([i])
input_arr.shape
plt.imshow(i)

pred=model.predict(input_arr)[0][0]
print(pred)

if pred<0.5:
  print("The MRI image is of BRAIN TUMOR\n")
else:
  print("The MRI image is of HEALTHY BRAIN\n")
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 0.49258128
# The MRI image is of BRAIN TUMOR
